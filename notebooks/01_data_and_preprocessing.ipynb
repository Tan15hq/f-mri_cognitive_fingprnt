# %%
# install required libraries
# !pip install --quiet nilearn nibabel numpy pandas scikit-learn scipy joblib matplotlib plotly
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 131.2 MB/s eta 0:00:00

# %%
# CELL A
import os, glob, json, hashlib, time
import numpy as np
import matplotlib.pyplot as plt

WORKDIR = '/content/drive/MyDrive/fmri_fingerprint'
TS_DIR = os.path.join(WORKDIR, 'timeseries')
CONN_DIR = os.path.join(WORKDIR, 'connectivity')
RESULTS_DIR = os.path.join(WORKDIR, 'results')
DOCS_DIR = os.path.join(WORKDIR, 'docs')
MANIFEST = os.path.join(WORKDIR, 'manifest_connectivity.csv')

for d in [WORKDIR, TS_DIR, CONN_DIR, RESULTS_DIR, DOCS_DIR]:
    os.makedirs(d, exist_ok=True)

print("WORKDIR:", WORKDIR)
# Out:
# WORKDIR: /content/drive/MyDrive/fmri_fingerprint
